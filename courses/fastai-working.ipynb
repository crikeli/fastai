# %%
# %matplotlib inline
import geopandas
import fiona
import rasterio
from osgeo import gdal
import os

# %%
curr_dir = os.getcwd()
print(curr_dir)
# Out:
# /Users/kelinchristi/fastai/courses

# %%
raster_path = '../../Documents/planet_labs/20170723_073614_1011_3B_Visual.tif'

# %%
data = rasterio.open(raster_path)

# %%
data.count, data.width, data.height
# Out:
# (4, 8953, 4433)

# %%
data.crs
# Out:
# CRS({'init': 'epsg:32636'})

# %%
from rasterio.plot import show
show(data)

# %%
data??
